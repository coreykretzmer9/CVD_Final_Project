# %%
import os
import csv
import pandas as pd
import matplotlib.pyplot as plt
import json
import time
import scipy.stats as stats

# %%
os.getcwd()
# Out:
# 'C:\\Users\\corey\\Desktop\\CVD_Final_Project\\Final Project'

# %%
all_data_df = pd.read_csv('SuperP_Group_Current_Working_Dataset.csv')

# %%
all_data_df.head()
# Out:
#    Unnamed: 0  FIPS Code       County, State  Population  Deaths  Crude Rate  \
# 0           0       1001  Autauga County, AL    144568.0   188.0       130.0
# 1           1       1003  Baldwin County, AL    514161.0   581.0       113.0
# 2           2       1005  Barbour County, AL     71488.0   118.0       165.1
# 3           3       1007     Bibb County, AL     62810.0   123.0       195.8
# 4           4       1009   Blount County, AL    148438.0   194.0       130.7
#
#    Median Household Income ($)  % <High School  % High School  % Associate  \
# 0                        53748            12.4           34.3         28.7
# 1                        50976            10.0           28.7         31.8
# 2                        32111            26.2           34.9         26.0
# 3                        40113            19.3           41.8         26.9
# 4                        46377            20.0           32.9         34.0
#
# ...

# %%
all_data_df.columns
# Out:
# Index(['Unnamed: 0', 'FIPS Code', 'County, State', 'Population', 'Deaths',
#        'Crude Rate', 'Median Household Income ($)', '% <High School',
#        '% High School', '% Associate', '% >Bachelor', 'MYS', 'Education Level',
#        'Income Level', 'State', 'County_y', 'Population Total', '% White',
#        '% Black', '% Native American', '% Asian', '% Pacific Islander',
#        '% Other', '% Two or More Races', 'Estimated Diabetes Rate Per 1,000',
#        '% Daily Smokers', '% Population Obese'],
#       dtype='object')

# %%
all_data_relevant_df = all_data_df[['FIPS Code', 'County, State', 'Population', 'Deaths',
       'Crude Rate', 'Median Household Income ($)', 'MYS', 'Estimated Diabetes Rate Per 1,000',
       '% Daily Smokers', '% Population Obese']]
all_data_relevant_df.head()
# Out:
#    FIPS Code       County, State  Population  Deaths  Crude Rate  \
# 0       1001  Autauga County, AL    144568.0   188.0       130.0
# 1       1003  Baldwin County, AL    514161.0   581.0       113.0
# 2       1005  Barbour County, AL     71488.0   118.0       165.1
# 3       1007     Bibb County, AL     62810.0   123.0       195.8
# 4       1009   Blount County, AL    148438.0   194.0       130.7
#
#    Median Household Income ($)     MYS  Estimated Diabetes Rate Per 1,000  \
# 0                        53748  14.294                               13.2
# 1                        50976  14.796                                9.3
# 2                        32111  13.028                               16.5
# 3                        40113  13.112                               13.7
# 4                        46377  13.328                               12.6
#
#    % Daily Smokers  % Population Obese
# 0            18.41                37.5
# 1            16.02                31.0
# ...
